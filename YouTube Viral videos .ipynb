# %%
#import pandas
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
filename = '.ipynb_checkpoints/viral_meta.csv'
df = pd.read_csv(filename)
df
# Out:
#         video_id                                        video_title  \
# 0    -_49VS4nuao        Elmo and Cookie Monster have some Adult Fun
# 1    -goXKtd6cPo                    First Blog / Dorkiness Prevails
# 2    -HePTmrV-og         We Love You Maria Venus Raj 22 Philippines
# 3    -kIJqXLMLwc         shiba inu white pupy 【超可愛い】【初公開】白柴くもくんの鳴き声
# 4    -UaW6zYQDQE                   Mariko Takahashi's Fitness Video
# ..           ...                                                ...
# 441  zAjWi663kXc                                    Zidane headbutt
# 442  zd7c5tQCs1I                                 Catch the Ice Dude
# 443  ZGjwe-BCfms      Evaporating Water in -30C in Yellowknife, NWT
# 444  ZstObB4RVsQ  Eating a Ghost Chili Pepper (Naga/Bhut Jolokia...
# 445  zTi_Zpl9MFk                      Girl Wrecks Hard On Bike Jump
#
#      view_count       category  duration_in_seconds               upload_time  \
# 0       1313791         Comedy                   42  2008-12-28T21:57:55.000Z
# 1       4484903           Film                   95  2006-06-16T18:49:21.000Z
# 2       3556190  Entertainment                  253  2010-08-24T08:27:12.000Z
# 3       5914475        Animals                   49  2009-09-19T05:53:24.000Z
# 4        590989          Howto                  210  2006-03-16T05:43:31.000Z
# ..          ...            ...                  ...                       ...
# 441     5985159         Sports                   53  2006-07-10T10:58:41.000Z
# 442    23840494         Comedy                   79  2012-09-28T14:59:53.000Z
# 443     8659010           Tech                   33  2010-01-02T00:35:00.000Z
# 444     2841485  Entertainment                  349  2011-10-11T05:18:35.000Z
# 445     1743823         Comedy                   46  2011-07-09T21:47:31.000Z
#
#     captured_time  avg_rate  max_rate  min_rate  num_raters  num_dislikes  \
# 0        01/18/13  4.921736       5.0       1.0        9864           193
# 1        01/18/13  3.255860       5.0       1.0       10068          4390
# 2        01/18/13  4.797153       5.0       1.0       16860           855
# 3        01/18/13  4.959495       5.0       1.0       39007           395
# 4        01/18/13  4.552616       5.0       1.0        1663           186
# ..            ...       ...       ...       ...         ...           ...
# 441      01/18/13  4.791225       5.0       1.0        5652           295
# 442      01/18/13  4.906035       5.0       1.0      107828          2533
# 443      01/18/13  4.954732       5.0       1.0       10957           124
# 444      01/18/13  4.668135       5.0       1.0       16115          1337
# 445      01/18/13  4.941563       5.0       1.0        4107            60
#
#      num_likes             uploader_id    uploader_name  \
# 0         9671  ZcSyg9WKALBO4r97-pjmAg       Dan Wilson
# 1         5678  VEfyEuLJpgw_y4jSgV8Rtg     lonelygirl15
# 2        16005  u1TBcXNK29GvIwud6rVJQw           lexlib
# 3        38612  RL7_KwtbtYqACtAaWXA6Tw    okanouefamily
# 4         1477  ajte6UFGsKtxCvNabt26RQ       vinylboy20
# ..         ...                     ...              ...
# 441       5357  zqeDsCw2Fnsf6vAD4aTqaA     metallica018
# 442     105295  aIGlN4-zeuM0i4jswYutCQ  MrRobcalifornia
# 443      10833  XYqi_6fN6oizmbVCR0astQ      samantha683
# 444      14778  DZESjYAwh-ws7ZSZZ8DKeg     skippy62able
# 445       4047  _cDEFDC0qY82rMTqN04cYQ       hawtwonder
#
#                                           uploader_url  \
# 0    https://gdata.youtube.com/feeds/api/users/dani...
# 1    https://gdata.youtube.com/feeds/api/users/lone...
# 2     https://gdata.youtube.com/feeds/api/users/lexlib
# 3    https://gdata.youtube.com/feeds/api/users/okan...
# 4    https://gdata.youtube.com/feeds/api/users/viny...
# ..                                                 ...
# 441  https://gdata.youtube.com/feeds/api/users/meta...
# 442  https://gdata.youtube.com/feeds/api/users/MrRo...
# 443  https://gdata.youtube.com/feeds/api/users/sama...
# 444  https://gdata.youtube.com/feeds/api/users/skip...
# 445  https://gdata.youtube.com/feeds/api/users/hawt...
#
#                                             video_desp
# 0    Discovered completely by accident by putting t...
# 1    So, I finally got a webcam and got it working ...
# 2    We are only among many who went wild. Irina, M...
# 3    生まれて9日目のくもくんです。 Thank you for watching this mo...
# 4    This is a mesmerizing and frightening video. I...
# ..                                                 ...
# 441  Zidane headbutts Materazzi in extra time of th...
# 442  http://soundcloud.com/bipole/sets/bipole    ht...
# 443  http://www.spectacularnwt.com On a winter day ...
# 444  This guy has never eaten a spicy thing in his ...
# 445  Rounded up the crew and headed off to the Alpi...
#
# [446 rows x 17 columns]

# %%
# Counting the video category names
plt.figure(figsize = (14,9))
gr = sns.countplot('category', data=df, palette="bright", order = df['category'].value_counts().index)
gr.set_xticklabels(gr.get_xticklabels(),rotation=45)
gr.set_title("Number of Viral videos by category", fontsize=20)
gr.set_xlabel("", fontsize=12)
gr.set_ylabel("Count", fontsize=12)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Following the initial exploratory analysis of our dataset, we are interested in answering a series of question to understand the features of viral videos
#  Viewers Engagement
# #### Users are more likely to engage(like, dislike, comment) in which category?

# %%
# We create the correlation matrix with .corr
corr_matrix = df.corr()

# %%
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)]= True
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(14, 12)) 
heatmap = sns.heatmap(corr_matrix, 
                      mask = mask,
                      square = True,
                      linewidths = .5,
                      cbar_kws = {'shrink': .4, 
                                'ticks' : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1, 
                      vmax = 1,
                      annot = True,
                      annot_kws = {'size': 12})

#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
corr_columns=[]
corr_mtrx=df[corr_columns].corr()
corr_mtrx

# %%
plt.figure(figsize = (14,12))
ax = sns.heatmap(corr_mtrx, linewidths=.5, annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b7e153836ff4> in <module>
#       1 plt.figure(figsize = (14,12))
# ----> 2 ax = sns.heatmap(corr_mtrx, linewidths=.5, annot=True, cmap='coolwarm')
#
# NameError: name 'corr_mtrx' is not defined

# %%
# Graphs to measure how many views, likes, dislikes and comments get by different categories
plt.figure(figsize = (14,9))

# Views distribution that shows watch rates of category names
g_v = sns.barplot(x="category", y="view_count", data=df, palette="bright")
g_v.set_xticklabels(g_v.get_xticklabels(),rotation=45)
g_v.set_title("Number of views by Category", fontsize=20)
g_v.set_xlabel("", fontsize=12)
g_v.set_ylabel("Views", fontsize=12)

# This turns off the scientific notation for the y axis
plt.ticklabel_format(style='plain', axis ='y')

# %%
# Graphs to measure how many views, likes, dislikes and comments get by different categories
plt.figure(figsize = (14,9))

# Views distribution that shows watch rates of category names
g_v = sns.barplot(x="category", y="num_likes", data=df, palette="bright")
g_v.set_xticklabels(g_v.get_xticklabels(),rotation=45)
g_v.set_title("Number of likes by category", fontsize=20)
g_v.set_xlabel("", fontsize=12)
g_v.set_ylabel("Likes", fontsize=12)

# This turns off the scientific notation for the y axis
plt.ticklabel_format(style='plain', axis ='y')

# %%
# Graphs to measure how many views, likes, dislikes and comments get by different categories
plt.figure(figsize = (14,9))

# Views distribution that shows watch rates of category names
g_v = sns.barplot(x="category", y="num_dislikes", data=df, palette="bright")
g_v.set_xticklabels(g_v.get_xticklabels(),rotation=45)
g_v.set_title("Number of dislikes by category", fontsize=20)
g_v.set_xlabel("", fontsize=12)
g_v.set_ylabel("Disikes", fontsize=12)

# This turns off the scientific notation for the y axis
plt.ticklabel_format(style='plain', axis ='y')

# %%
# Graphs to measure how many views, likes, dislikes and comments get by different categories
plt.figure(figsize = (14,9))

# Views distribution that shows watch rates of category names
g_v = sns.barplot(x="category", y="upload_time", data=df, palette="bright")
g_v.set_xticklabels(g_v.get_xticklabels(),rotation=45)
g_v.set_title("Number of days viral by Category", fontsize=20)
g_v.set_xlabel("", fontsize=12)
g_v.set_ylabel("Number of days viral", fontsize=12)

# This turns off the scientific notation for the y axis
plt.ticklabel_format(style='plain', axis ='y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-642f823e7250> in <module>
#       3
#       4 # Views distribution that shows watch rates of category names
# ----> 5 g_v = sns.barplot(x="category", y="upload_time", data=df, palette="bright")
#       6 g_v.set_xticklabels(g_v.get_xticklabels(),rotation=45)
#       7 g_v.set_title("Number of days viral by Category", fontsize=20)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1600                  errwidth, capsize, dodge):
#    1601         """Initialize the plotter."""
# -> 1602         self.establish_variables(x, y, hue, data, orient,
#    1603                                  order, hue_order, units)
#    1604         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153
#     154             # Figure out the plotting orientation
# --> 155             orient = self.infer_orient(x, y, orient)
#     156
#     157             # Option 2a:
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in infer_orient(self, x, y, orient)
#     352         elif is_not_numeric(y):
#     353             if is_not_numeric(x):
# --> 354                 raise ValueError(no_numeric)
#     355             else:
#     356                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.
