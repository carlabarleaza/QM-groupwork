# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as pyplot


path = './USvideos.csv'
df1 = pd.read_csv(path)

# %%
df1.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#         category_id              publish_time  \
# 0  People and Vlogs  2017-11-13T17:13:01.000Z
# 1     Entertainment  2017-11-13T07:30:00.000Z
# 2            Comedy  2017-11-12T19:05:24.000Z
# 3     Entertainment  2017-11-13T11:00:04.000Z
# 4     Entertainment  2017-11-12T18:01:41.000Z
#
# ...

# %%
category = df1.loc[:,'category_id'].values

# %%
chart = df1['category_id'].hist(edgecolor = 'black', bins = 20)
pyplot.xticks(rotation = 90)
pyplot.xlabel('Category')
pyplot.ylabel('Number of videos)')
pyplot.title('The Category of each video vs \n amount of videos in US trending page 2013-2016')
# Out:
# Text(0.5, 1.0, 'The Category of each video vs \n amount of videos in US trending page 2013-2016')
