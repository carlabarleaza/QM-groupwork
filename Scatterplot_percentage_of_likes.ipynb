# %% [markdown]
# # Getting CSV file

# %%
import pandas as pd
filename = './viral_meta.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#         video_id                                        video_title  \
# 0    -_49VS4nuao        Elmo and Cookie Monster have some Adult Fun
# 1    -goXKtd6cPo                    First Blog / Dorkiness Prevails
# 2    -HePTmrV-og         We Love You Maria Venus Raj 22 Philippines
# 3    -kIJqXLMLwc         shiba inu white pupy 【超可愛い】【初公開】白柴くもくんの鳴き声
# 4    -UaW6zYQDQE                   Mariko Takahashi's Fitness Video
# ..           ...                                                ...
# 441  zAjWi663kXc                                    Zidane headbutt
# 442  zd7c5tQCs1I                                 Catch the Ice Dude
# 443  ZGjwe-BCfms      Evaporating Water in -30C in Yellowknife, NWT
# 444  ZstObB4RVsQ  Eating a Ghost Chili Pepper (Naga/Bhut Jolokia...
# 445  zTi_Zpl9MFk                      Girl Wrecks Hard On Bike Jump
#
#      view_count       category  duration_in_seconds               upload_time  \
# ...

# %% [markdown]
# # Checking the types of data in csv file

# %%
df.dtypes
# Out:
# video_id                object
# video_title             object
# view_count               int64
# category                object
# duration_in_seconds      int64
# upload_time             object
# captured_time           object
# avg_rate               float64
# max_rate               float64
# min_rate               float64
# num_raters               int64
# num_dislikes             int64
# num_likes                int64
# uploader_id             object
# uploader_name           object
# uploader_url            object
# video_desp              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             446 non-null    object
#  1   video_title          446 non-null    object
#  2   view_count           446 non-null    int64
#  3   category             446 non-null    object
#  4   duration_in_seconds  446 non-null    int64
#  5   upload_time          446 non-null    object
#  6   captured_time        446 non-null    object
#  7   avg_rate             446 non-null    float64
#  8   max_rate             446 non-null    float64
#  9   min_rate             446 non-null    float64
#  10  num_raters           446 non-null    int64
#  11  num_dislikes         446 non-null    int64
#  12  num_likes            446 non-null    int64
#  13  uploader_id          446 non-null    object
#  14  uploader_name        446 non-null    object
# ...

# %% [markdown]
# # Slicing the data

# %%
data_wanted = df[['view_count','num_dislikes', 'num_likes']]
data_wanted
# Out:
#      view_count  num_dislikes  num_likes
# 0       1313791           193       9671
# 1       4484903          4390       5678
# 2       3556190           855      16005
# 3       5914475           395      38612
# 4        590989           186       1477
# ..          ...           ...        ...
# 441     5985159           295       5357
# 442    23840494          2533     105295
# 443     8659010           124      10833
# 444     2841485          1337      14778
# 445     1743823            60       4047
#
# [446 rows x 3 columns]

# %%
df['percentage_of_likes'] = (((df['num_likes'])/(df['num_dislikes'] + df['num_likes'])) * 100).round()
df
# Out:
#         video_id                                        video_title  \
# 0    -_49VS4nuao        Elmo and Cookie Monster have some Adult Fun
# 1    -goXKtd6cPo                    First Blog / Dorkiness Prevails
# 2    -HePTmrV-og         We Love You Maria Venus Raj 22 Philippines
# 3    -kIJqXLMLwc         shiba inu white pupy 【超可愛い】【初公開】白柴くもくんの鳴き声
# 4    -UaW6zYQDQE                   Mariko Takahashi's Fitness Video
# ..           ...                                                ...
# 441  zAjWi663kXc                                    Zidane headbutt
# 442  zd7c5tQCs1I                                 Catch the Ice Dude
# 443  ZGjwe-BCfms      Evaporating Water in -30C in Yellowknife, NWT
# 444  ZstObB4RVsQ  Eating a Ghost Chili Pepper (Naga/Bhut Jolokia...
# 445  zTi_Zpl9MFk                      Girl Wrecks Hard On Bike Jump
#
#      view_count       category  duration_in_seconds               upload_time  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             446 non-null    object
#  1   video_title          446 non-null    object
#  2   view_count           446 non-null    int64
#  3   category             446 non-null    object
#  4   duration_in_seconds  446 non-null    int64
#  5   upload_time          446 non-null    object
#  6   captured_time        446 non-null    object
#  7   avg_rate             446 non-null    float64
#  8   max_rate             446 non-null    float64
#  9   min_rate             446 non-null    float64
#  10  num_raters           446 non-null    int64
#  11  num_dislikes         446 non-null    int64
#  12  num_likes            446 non-null    int64
#  13  uploader_id          446 non-null    object
#  14  uploader_name        446 non-null    object
# ...

# %%
percentage_of_likes = df.loc[:,'percentage_of_likes'].values
total_views = df.loc[:,'view_count'].values

# %%
percentage_of_likes
# Out:
# array([ 98.,  56.,  95.,  99.,  89.,  98.,  97.,  98.,  97.,  87.,  98.,
#         97.,  94.,  94.,  97.,  96.,  98.,  99.,  72.,  95.,  50.,  98.,
#         92.,  92.,  97.,  97.,  92.,  98.,  96.,  98.,  98.,  86.,  87.,
#         97.,  92.,  80.,  97.,  99.,  98.,  96.,  99.,  98.,  94.,  97.,
#         99.,  97.,  96.,  98.,  97.,  98.,  99.,  98.,  98., 100.,  93.,
#         82.,  90.,  97.,  96.,  92.,  93.,  98.,  98.,  94.,  98.,  93.,
#         85.,  97.,  77.,  98.,  99.,  82.,  92.,  93.,  97.,  98.,  99.,
#         93.,  38.,  95.,  95.,  97.,  98.,  99.,  92.,  92.,  99.,  75.,
#         99.,  97.,  96.,  64.,  97.,  99.,  95.,  98.,  90.,  85.,  66.,
#         97.,  95.,  96.,  91.,  98.,  86.,  93.,  98.,  98.,  97.,  96.,
#         68.,  99.,  99.,  98.,  96.,  97.,  96.,  85.,  96.,  99.,  95.,
#         97.,  97., 100.,  88.,  99.,  95.,  97.,  97.,  97.,  87.,  94.,
#         97.,  96.,  99., 100.,  98.,  99.,  95.,  99.,  97.,  93.,  98.,
# ...

# %%
total_views
# Out:
# array([   1313791,    4484903,    3556190,    5914475,     590989,
#            737883,    4316512,    1725068,   77430734,  508093166,
#           9213134,    7563056,    1422960,    1430085,     820890,
#           1009912,    6477020,    2707770,    2227794,    1872964,
#            700385,     948354,   11017464,     959966,   18823165,
#           3323206,     625603,    9345219,    8137361,    1914006,
#            583896,    2556641,    1028480,    3003892,    4833857,
#           7967666,    1855175,   41982160,    1075963,     874588,
#           1103838,    7969953,     501546,    3102558,    5816656,
#          79209049,     574342,    4148023,     944804,    5645552,
#           7653664,   48868669,     693298,    1037333,   17209154,
#           1978664,    6806292,    1430844,    7082024,    1076454,
#            683165,   12789541,     895105,   24485759,     835680,
#           6726633,    5677508,    1574018,    6361547,     680298,
# ...

# %%
plt.plot(total_views, percentage_of_likes)

# %%
plt.style.available
plt.plot(total_views, percentage_of_likes)

# %%
import numpy as np
area = np.pi*3
colors = (0,0,0)
plt.scatter(total_views, percentage_of_likes, s=area, c=colors, alpha=0.5)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
